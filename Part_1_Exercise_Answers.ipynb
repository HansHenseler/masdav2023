# %% [markdown]
# <a href="https://colab.research.google.com/github/HansHenseler/masdav2023/blob/main/Part_1_Exercise_Answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python for Data Analysis introduction
#
# Master of Advanced Studies in Digital Forensics & Cyber Investigation
#
# Data Analytics and Visualization for Digital Forensics
#
# (c) Hans Henseler, 2023
#
# This exercise starts with examples of most common data analysis tasks with Python, from the features of Python itself to using modules like Pandas with a few exercises that you can try to accomplish yourself.

# %% [markdown]
# # Part 1 Answers

# %%
# initialize dataframes to start where we left of with the instructions
#
import numpy as np
import pandas as pd
df = pd.read_excel('DirPrint_Filelist - clean.xlsx')
df
# Out:
#        Attributes             Created             LastMod             LastAcc  \
# 0        ---A---- 2021-01-05 19:19:00 2021-01-05 19:19:00 2021-08-12 20:58:00
# 1             NaN 2021-04-22 19:57:00 2021-04-22 19:57:00 2021-08-12 20:58:00
# 2        ---A---- 2020-08-18 10:52:00 2020-08-18 10:54:00 2021-08-12 20:58:00
# 3        --SA---- 2020-11-19 09:44:00 2021-08-12 08:45:00 2021-08-12 20:58:00
# 4        ---A---- 2021-04-22 18:53:00 2021-04-22 18:53:00 2021-08-12 20:58:00
# ...           ...                 ...                 ...                 ...
# 255826        NaN 2020-11-19 04:44:00 2020-11-19 04:57:00 2021-07-08 19:35:00
# 255827        NaN 2021-04-22 20:02:00 2020-09-05 03:54:00 2021-07-08 19:35:00
# 255828        NaN 2020-11-19 04:44:00 2020-11-19 04:57:00 2021-07-08 19:35:00
# 255829        NaN 2020-11-19 04:44:00 2020-11-19 04:57:00 2021-07-08 19:35:00
# 255830        NaN 2020-11-19 04:44:00 2020-11-19 04:57:00 2021-07-08 19:35:00
#
#            Size                                Name  \
# 0         22639                     aksdrvsetup.log
# 1         77824                           bfsvc.exe
# 2       3145782                          BGInfo.bmp
# 3         67584                        bootstat.dat
# 4           762                        comsetup.log
# ...         ...                                 ...
# 255826   375276                     WindowsBase.dll
# 255827  1257472                     WindowsBase.dll
# 255828   312556      System.Workflow.Activities.dll
# 255829   484222  System.Workflow.ComponentModel.dll
# 255830   149554         System.Workflow.Runtime.dll
#
#                                                      Path  \
# 0                              C:\Windows\aksdrvsetup.log
# 1                                    C:\Windows\bfsvc.exe
# 2                                   C:\Windows\BGInfo.bmp
# 3                                 C:\Windows\bootstat.dat
# 4                                 C:\Windows\comsetup.log
# ...                                                   ...
# 255826  C:\Windows\WinSxS\x86_wpf-windowsbase_31bf3856...
# 255827  C:\Windows\WinSxS\x86_wpf-windowsbase_31bf3856...
# 255828  C:\Windows\WinSxS\x86_wwf-system.workflow.acti...
# 255829  C:\Windows\WinSxS\x86_wwf-system.workflow.comp...
# 255830  C:\Windows\WinSxS\x86_wwf-system.workflow.runt...
#
#                                                    Folder  Ext  \
# 0                                             C:\Windows\  log
# 1                                             C:\Windows\  exe
# 2                                             C:\Windows\  bmp
# 3                                             C:\Windows\  dat
# 4                                             C:\Windows\  log
# ...                                                   ...  ...
# 255826  C:\Windows\WinSxS\x86_wpf-windowsbase_31bf3856...  dll
# 255827  C:\Windows\WinSxS\x86_wpf-windowsbase_31bf3856...  dll
# 255828  C:\Windows\WinSxS\x86_wwf-system.workflow.acti...  dll
# 255829  C:\Windows\WinSxS\x86_wwf-system.workflow.comp...  dll
# 255830  C:\Windows\WinSxS\x86_wwf-system.workflow.runt...  dll
#
#                                      Md5
# 0       50D08E904772E94EB4B16817EB5BE4F1
# 1       862251351EC170BB3BD59CB219491811
# 2       EC80E9F3112F716063C273FC1F75F552
# 3       E68A42FC4CD032E168A66925D63CB96C
# 4       FFD6B7D88934C99E34D5A823B56A03DE
# ...                                  ...
# 255826  4F6CFC1F7C771075F17D039EB24C6276
# 255827  8280BBD8640ECF3826460903760D9774
# 255828  DE9176C367D11585D297ACC50E113676
# 255829  B92ADB66E47707BDDCC62B850A4201E3
# 255830  412EF3105A13CF3111539C74E7B7F190
#
# [255831 rows x 10 columns]

# %% [markdown]
# ## 1 Use a regular expression to select office files based on file extension

# %%
# here is a simple example using a regular expression to find all rows with xls in the Ext colum
df[df.Ext.str.match(r'(xls|doc|xlsx|docx|ppt|pptx)')==True]
# Out:
#        Attributes             Created             LastMod             LastAcc  \
# 182974        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 182975   ---A---- 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 182976        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 190588        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-08-12 21:19:00
# 190589   ---A---- 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-08-12 21:19:00
# 190590        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-08-12 21:19:00
# 209453        NaN 2019-12-07 11:08:00 2019-12-07 11:08:00 2021-07-08 19:38:00
# 209454   ---A---- 2019-12-07 11:08:00 2019-12-07 11:08:00 2021-07-08 19:38:00
# 209455        NaN 2019-12-07 11:08:00 2019-12-07 11:08:00 2021-07-08 19:38:00
# 250336        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 250337   ---A---- 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 250338        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
#
#          Size                 Name  \
# 182974  24064  MsoIrmProtector.doc
# 182975   8704  MsoIrmProtector.ppt
# 182976  13824  MsoIrmProtector.xls
# 190588  24064  MsoIrmProtector.doc
# 190589   8704  MsoIrmProtector.ppt
# 190590  13824  MsoIrmProtector.xls
# 209453  24064  MsoIrmProtector.doc
# 209454   8704  MsoIrmProtector.ppt
# 209455  13824  MsoIrmProtector.xls
# 250336  24064  MsoIrmProtector.doc
# 250337   8704  MsoIrmProtector.ppt
# 250338  13824  MsoIrmProtector.xls
#
#                                                      Path  \
# 182974      C:\Windows\System32\MSDRM\MsoIrmProtector.doc
# 182975      C:\Windows\System32\MSDRM\MsoIrmProtector.ppt
# 182976      C:\Windows\System32\MSDRM\MsoIrmProtector.xls
# 190588      C:\Windows\SysWOW64\MSDRM\MsoIrmProtector.doc
# 190589      C:\Windows\SysWOW64\MSDRM\MsoIrmProtector.ppt
# 190590      C:\Windows\SysWOW64\MSDRM\MsoIrmProtector.xls
# 209453  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...
# 209454  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...
# 209455  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...
# 250336  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...
# 250337  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...
# 250338  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...
#
#                                                    Folder  Ext  \
# 182974                         C:\Windows\System32\MSDRM\  doc
# 182975                         C:\Windows\System32\MSDRM\  ppt
# 182976                         C:\Windows\System32\MSDRM\  xls
# 190588                         C:\Windows\SysWOW64\MSDRM\  doc
# 190589                         C:\Windows\SysWOW64\MSDRM\  ppt
# 190590                         C:\Windows\SysWOW64\MSDRM\  xls
# 209453  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...  doc
# 209454  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...  ppt
# 209455  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...  xls
# 250336  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...  doc
# 250337  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...  ppt
# 250338  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...  xls
#
#                                      Md5
# 182974  33E940FBEB47478645B849EFC85BAB08
# 182975  3FD50116F4D8158A3986296E92650CDD
# 182976  277F810450728D90009B4D73D108B744
# 190588  33E940FBEB47478645B849EFC85BAB08
# 190589  3FD50116F4D8158A3986296E92650CDD
# 190590  277F810450728D90009B4D73D108B744
# 209453  33E940FBEB47478645B849EFC85BAB08
# 209454  3FD50116F4D8158A3986296E92650CDD
# 209455  277F810450728D90009B4D73D108B744
# 250336  33E940FBEB47478645B849EFC85BAB08
# 250337  3FD50116F4D8158A3986296E92650CDD
# 250338  277F810450728D90009B4D73D108B744

# %%
# Here is another method
#
# Regular expression pattern for office file extensions
pattern = '^(doc|docx|xls|xlsx|ppt|pptx)$'

# Filter rows based on the pattern
df[df['Ext'].str.contains(pattern, case=False, na=False)]
# Out:
# <ipython-input-11-4d9ac33e8ab4>:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[df['Ext'].str.contains(pattern, case=False, na=False)]
#        Attributes             Created             LastMod             LastAcc  \
# 174076   ---A---- 2015-07-30 03:24:00 2015-07-30 03:24:00 2020-08-20 10:24:00
# 182974        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 182975   ---A---- 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 182976        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 190588        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-08-12 21:19:00
# 190589   ---A---- 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-08-12 21:19:00
# 190590        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-08-12 21:19:00
# 209453        NaN 2019-12-07 11:08:00 2019-12-07 11:08:00 2021-07-08 19:38:00
# 209454   ---A---- 2019-12-07 11:08:00 2019-12-07 11:08:00 2021-07-08 19:38:00
# 209455        NaN 2019-12-07 11:08:00 2019-12-07 11:08:00 2021-07-08 19:38:00
# 250336        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 250337   ---A---- 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
# 250338        NaN 2019-12-07 11:09:00 2019-12-07 11:09:00 2021-07-08 19:37:00
#
#          Size                 Name  \
# 174076   5739         EXCEL12.XLSX
# 182974  24064  MsoIrmProtector.doc
# 182975   8704  MsoIrmProtector.ppt
# 182976  13824  MsoIrmProtector.xls
# 190588  24064  MsoIrmProtector.doc
# 190589   8704  MsoIrmProtector.ppt
# 190590  13824  MsoIrmProtector.xls
# 209453  24064  MsoIrmProtector.doc
# 209454   8704  MsoIrmProtector.ppt
# 209455  13824  MsoIrmProtector.xls
# 250336  24064  MsoIrmProtector.doc
# 250337   8704  MsoIrmProtector.ppt
# 250338  13824  MsoIrmProtector.xls
#
#                                                      Path  \
# 174076                   C:\Windows\SHELLNEW\EXCEL12.XLSX
# 182974      C:\Windows\System32\MSDRM\MsoIrmProtector.doc
# 182975      C:\Windows\System32\MSDRM\MsoIrmProtector.ppt
# 182976      C:\Windows\System32\MSDRM\MsoIrmProtector.xls
# 190588      C:\Windows\SysWOW64\MSDRM\MsoIrmProtector.doc
# 190589      C:\Windows\SysWOW64\MSDRM\MsoIrmProtector.ppt
# 190590      C:\Windows\SysWOW64\MSDRM\MsoIrmProtector.xls
# 209453  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...
# 209454  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...
# 209455  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...
# 250336  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...
# 250337  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...
# 250338  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...
#
#                                                    Folder   Ext  \
# 174076                               C:\Windows\SHELLNEW\  XLSX
# 182974                         C:\Windows\System32\MSDRM\   doc
# 182975                         C:\Windows\System32\MSDRM\   ppt
# 182976                         C:\Windows\System32\MSDRM\   xls
# 190588                         C:\Windows\SysWOW64\MSDRM\   doc
# 190589                         C:\Windows\SysWOW64\MSDRM\   ppt
# 190590                         C:\Windows\SysWOW64\MSDRM\   xls
# 209453  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...   doc
# 209454  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...   ppt
# 209455  C:\Windows\WinSxS\amd64_microsoft-windows-r..t...   xls
# 250336  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...   doc
# 250337  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...   ppt
# 250338  C:\Windows\WinSxS\wow64_microsoft-windows-r..t...   xls
#
#                                      Md5
# 174076  7FFB55F6D4F1851170D48B0C26986441
# 182974  33E940FBEB47478645B849EFC85BAB08
# 182975  3FD50116F4D8158A3986296E92650CDD
# 182976  277F810450728D90009B4D73D108B744
# 190588  33E940FBEB47478645B849EFC85BAB08
# 190589  3FD50116F4D8158A3986296E92650CDD
# 190590  277F810450728D90009B4D73D108B744
# 209453  33E940FBEB47478645B849EFC85BAB08
# 209454  3FD50116F4D8158A3986296E92650CDD
# 209455  277F810450728D90009B4D73D108B744
# 250336  33E940FBEB47478645B849EFC85BAB08
# 250337  3FD50116F4D8158A3986296E92650CDD
# 250338  277F810450728D90009B4D73D108B744

# %% [markdown]
# ## 2 Remove duplicate entries in df based on the md5 value.

# %%
df.shape
# Out:
# (255831, 10)

# %%
df_dedup = df.drop_duplicates('Md5', keep='last')
df_dedup.shape
# Out:
# (147340, 10)

# %% [markdown]
# ## 3 For a given file, find if it has duplicates and list the folders where duplicates are located

# %%
df.duplicated('Md5')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 255826    False
# 255827     True
# 255828    False
# 255829    False
# 255830    False
# Length: 255831, dtype: bool

# %%
# Apparently record 255826 is duplicated. We can print it's Md5 value using the df.loc attribute
#
df.loc[255827].Md5
# Out:
# '8280BBD8640ECF3826460903760D9774'

# %%
# We can select all duplicates with a filter
#
df[df.Md5 == '8280BBD8640ECF3826460903760D9774']
# Out:
#        Attributes             Created             LastMod             LastAcc  \
# 245334        NaN 2021-04-22 20:02:00 2020-09-05 03:54:00 2021-07-08 19:35:00
# 255827        NaN 2021-04-22 20:02:00 2020-09-05 03:54:00 2021-07-08 19:35:00
#
#            Size             Name  \
# 245334  1257472  WindowsBase.dll
# 255827  1257472  WindowsBase.dll
#
#                                                      Path  \
# 245334  C:\Windows\WinSxS\msil_windowsbase_31bf3856ad3...
# 255827  C:\Windows\WinSxS\x86_wpf-windowsbase_31bf3856...
#
#                                                    Folder  Ext  \
# 245334  C:\Windows\WinSxS\msil_windowsbase_31bf3856ad3...  dll
# 255827  C:\Windows\WinSxS\x86_wpf-windowsbase_31bf3856...  dll
#
#                                      Md5
# 245334  8280BBD8640ECF3826460903760D9774
# 255827  8280BBD8640ECF3826460903760D9774

# %%
# Here is how you can get an overview of top duplicate Md5 values

df.Md5.value_counts()
# Out:
# Not Available                       1267
# C8E0304DEFE5A9CBED06CE795FDC6347     304
# 67D426DC9EF846B3B5F082A5210CD0B4     304
# 8007DAB1F7B337FE863085F4C933D959      88
# 282D83E34E05CEF90F97BDBA9FC85E1D      72
#                                     ...
# 35C00281553E246A36B7EF932AD642BB       1
# ECC2FEA0C9C6A644275B123AFA9DD285       1
# 8562DE10F5BC5162992C3BF806A9EA6D       1
# D531331A8E572BF9523CD2A928EE2608       1
# 412EF3105A13CF3111539C74E7B7F190       1
# Name: Md5, Length: 147340, dtype: int64

# %%
# How does a Md5 look like for a empty file?

df[df.Size==0]
# Out:
#        Attributes             Created             LastMod             LastAcc  \
# 24       ---A---- 2021-04-22 18:51:00 2021-04-22 18:51:00 2021-04-22 18:51:00
# 53       RH-A---- 2021-04-22 18:52:00 2021-04-22 18:52:00 2021-04-22 18:52:00
# 54       RH------ 2021-04-22 18:52:00 2021-04-22 18:52:00 2021-04-22 18:52:00
# 1762     RH-A---- 2020-08-18 11:00:00 2020-08-18 11:00:00 2020-08-18 11:00:00
# 1954     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 1956     ---A---- 2021-04-15 01:55:00 2021-04-15 01:55:00 2021-04-15 01:55:00
# 1958     ---A---- 2021-05-07 18:00:00 2021-05-07 18:00:00 2021-05-07 18:00:00
# 1960     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 1968     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 1970     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 1978     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 1980     ---A---- 2020-09-10 00:08:00 2020-09-10 00:08:00 2020-09-10 00:08:00
# 1982     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 1994     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 2004     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 2010     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 2018     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 2024     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 2032     ---A---- 2020-08-18 10:51:00 2020-08-18 10:51:00 2020-08-18 10:51:00
# 2267     ---A---- 2021-04-22 18:50:00 2021-08-10 11:28:00 2021-08-10 11:28:00
# 4820     ---A---- 2019-07-29 10:24:00 2019-07-29 10:24:00 2019-07-29 10:24:00
# 4822     ---A---- 2020-08-20 11:20:00 2020-08-20 11:20:00 2020-08-20 11:20:00
# 5761     R--A---- 2018-09-19 23:32:00 2018-09-19 23:32:00 2020-09-09 16:39:00
# 8441     -HSAC--- 2021-04-22 18:47:00 2021-04-22 18:47:00 2021-04-22 18:47:00
# 8442     -HSAC--- 2021-04-22 18:47:00 2021-04-22 18:47:00 2021-04-22 18:47:00
# 8574     -HSAC--- 2020-08-18 09:36:00 2020-08-18 09:36:00 2020-08-18 00:00:00
# 8575     -HSAC--- 2020-08-18 09:36:00 2020-08-18 09:36:00 2020-08-18 00:00:00
# 8590     ---AC--- 2021-04-22 18:50:00 2021-04-22 18:50:00 2021-04-22 18:50:00
# 182320   ---A---- 2021-07-08 12:14:00 2021-07-08 12:14:00 2021-07-08 12:14:00
# 182321   ---A---- 2021-07-08 12:14:00 2021-07-08 12:14:00 2021-07-08 12:14:00
# 182322   ---A---- 2021-07-08 12:14:00 2021-07-08 12:14:00 2021-07-08 12:14:00
# 182323   ---A---- 2021-07-08 12:14:00 2021-07-08 12:14:00 2021-07-08 12:14:00
# 182324   ---A---- 2021-07-08 12:14:00 2021-07-08 12:14:00 2021-07-08 12:14:00
# 182325   ---A---- 2021-07-08 12:14:00 2021-07-08 12:14:00 2021-07-08 12:14:00
#
#         Size                                               Name  \
# 24         0                                       setuperr.log
# 53         0                                PublisherPolicy.tme
# 54         0                                       pubpol66.dat
# 1762       0                                         skpswi.dat
# 1954       0                                       00000001.msg
# 1956       0                                       00000001.msg
# 1958       0                                       00000001.msg
# 1960       0                                       00000001.msg
# 1968       0                                       00000001.msg
# 1970       0                                       00000001.msg
# 1978       0                                       00000001.msg
# 1980       0                                       00000001.msg
# 1982       0                                       00000001.msg
# 1994       0                                       00000001.msg
# 2004       0                                       00000001.msg
# 2010       0                                       00000001.msg
# 2018       0                                       00000001.msg
# 2024       0                                       00000001.msg
# 2032       0                                       00000001.msg
# 2267       0                                         PASSWD.LOG
# 4820       0  wix{C807A481-8562-4A9F-AE2B-DD28DCB4BD88}.Sche...
# 4822       0  wix{CE46F02A-697E-485C-97EF-0171657D91A2}.Sche...
# 5761       0                                         icudtl.dat
# 8441       0                                           BCD.LOG1
# 8442       0                                           BCD.LOG2
# 8574       0                                           BCD.LOG1
# 8575       0                                           BCD.LOG2
# 8590       0                                       setuperr.log
# 182320     0                                        DEL2D6F.tmp
# 182321     0                                        DEL2DAF.tmp
# 182322     0                                        DEL2DC0.tmp
# 182323     0                                        DEL2DE0.tmp
# 182324     0                                        DEL2DF0.tmp
# 182325     0                                        DEL2E01.tmp
#
#                                                      Path  \
# 24                                C:\Windows\setuperr.log
# 53                C:\Windows\assembly\PublisherPolicy.tme
# 54                       C:\Windows\assembly\pubpol66.dat
# 1762             C:\Windows\CCM\Inventory\Temp\skpswi.dat
# 1954    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1956    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1958    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1960    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1968    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1970    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1978    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1980    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1982    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 1994    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 2004    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 2010    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 2018    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 2024    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 2032    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...
# 2267                          C:\Windows\debug\PASSWD.LOG
# 4820    C:\Windows\Installer\wix{C807A481-8562-4A9F-AE...
# 4822    C:\Windows\Installer\wix{CE46F02A-697E-485C-97...
# 5761    C:\Windows\Installer\$PatchCache$\Managed\68AB...
# 8441    C:\Windows\Panther\Rollback\EFI\Microsoft\Boot...
# 8442    C:\Windows\Panther\Rollback\EFI\Microsoft\Boot...
# 8574    C:\Windows\Panther\Rollback\EFI\Microsoft\Reco...
# 8575    C:\Windows\Panther\Rollback\EFI\Microsoft\Reco...
# 8590           C:\Windows\Panther\UnattendGC\setuperr.log
# 182320   C:\Windows\System32\DriverStore\Temp\DEL2D6F.tmp
# 182321   C:\Windows\System32\DriverStore\Temp\DEL2DAF.tmp
# 182322   C:\Windows\System32\DriverStore\Temp\DEL2DC0.tmp
# 182323   C:\Windows\System32\DriverStore\Temp\DEL2DE0.tmp
# 182324   C:\Windows\System32\DriverStore\Temp\DEL2DF0.tmp
# 182325   C:\Windows\System32\DriverStore\Temp\DEL2E01.tmp
#
#                                                    Folder   Ext  \
# 24                                            C:\Windows\   log
# 53                                   C:\Windows\assembly\   tme
# 54                                   C:\Windows\assembly\   dat
# 1762                       C:\Windows\CCM\Inventory\Temp\   dat
# 1954    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1956    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1958    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1960    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1968    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1970    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1978    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1980    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1982    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 1994    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 2004    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 2010    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 2018    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 2024    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 2032    C:\Windows\CCM\ServiceData\Messaging\EndpointQ...   msg
# 2267                                    C:\Windows\debug\   LOG
# 4820                                C:\Windows\Installer\   rmi
# 4822                                C:\Windows\Installer\   rmi
# 5761    C:\Windows\Installer\$PatchCache$\Managed\68AB...   dat
# 8441      C:\Windows\Panther\Rollback\EFI\Microsoft\Boot\  LOG1
# 8442      C:\Windows\Panther\Rollback\EFI\Microsoft\Boot\  LOG2
# 8574    C:\Windows\Panther\Rollback\EFI\Microsoft\Reco...  LOG1
# 8575    C:\Windows\Panther\Rollback\EFI\Microsoft\Reco...  LOG2
# 8590                       C:\Windows\Panther\UnattendGC\   log
# 182320              C:\Windows\System32\DriverStore\Temp\   tmp
# 182321              C:\Windows\System32\DriverStore\Temp\   tmp
# 182322              C:\Windows\System32\DriverStore\Temp\   tmp
# 182323              C:\Windows\System32\DriverStore\Temp\   tmp
# 182324              C:\Windows\System32\DriverStore\Temp\   tmp
# 182325              C:\Windows\System32\DriverStore\Temp\   tmp
#
#                                      Md5
# 24      D41D8CD98F00B204E9800998ECF8427E
# 53      D41D8CD98F00B204E9800998ECF8427E
# 54      D41D8CD98F00B204E9800998ECF8427E
# 1762                       Not Available
# 1954                       Not Available
# 1956                       Not Available
# 1958                       Not Available
# 1960                       Not Available
# 1968                       Not Available
# 1970                       Not Available
# 1978                       Not Available
# 1980                       Not Available
# 1982                       Not Available
# 1994                       Not Available
# 2004                       Not Available
# 2010                       Not Available
# 2018                       Not Available
# 2024                       Not Available
# 2032                       Not Available
# 2267    D41D8CD98F00B204E9800998ECF8427E
# 4820    D41D8CD98F00B204E9800998ECF8427E
# 4822    D41D8CD98F00B204E9800998ECF8427E
# 5761    D41D8CD98F00B204E9800998ECF8427E
# 8441    D41D8CD98F00B204E9800998ECF8427E
# 8442    D41D8CD98F00B204E9800998ECF8427E
# 8574    D41D8CD98F00B204E9800998ECF8427E
# 8575    D41D8CD98F00B204E9800998ECF8427E
# 8590                       Not Available
# 182320  D41D8CD98F00B204E9800998ECF8427E
# 182321  D41D8CD98F00B204E9800998ECF8427E
# 182322  D41D8CD98F00B204E9800998ECF8427E
# 182323  D41D8CD98F00B204E9800998ECF8427E
# 182324  D41D8CD98F00B204E9800998ECF8427E
# 182325  D41D8CD98F00B204E9800998ECF8427E

# %% [markdown]
# ## 4 Create a pivot table showing number of files per month based on data last modified

# %%
# Set the index to the LastMod column

df_date = df.set_index("LastMod")

# %%
df_date.pivot_table(index=[df_date.index.year,df_date.index.month],values='Size',aggfunc=['count','sum'])
# Out:
#                   count         sum
#                    Size        Size
# LastMod LastMod
# 1998    6             2     1219168
# 2001    1             1        5902
# 2008    7             1      853504
#         8             1      242176
# 2009    3             4      748832
# ...                 ...         ...
# 2021    4         18268  3769956999
#         5          1208   936792928
#         6         70846   923416400
#         7        101676  4980888513
#         8          1163   843618773
#
# [89 rows x 2 columns]

# %% [markdown]
# ## 5 Create a pivot table listing number of files vs file extension

# %%
pivot_table = df.pivot_table(index='Ext',values='Name',aggfunc=['count'])
print(pivot_table)
# Out:
#                                      count
#                                       Name
# Ext
# 1                                        1
# 11                                       3
# 1033                                     4
# 05F0B5F5_44A8_3793_976B_A4F17AECF92C     9
# 07275332_82E4_4820_9FDD_2423CD8DAA85   152
# ...                                    ...
# xslt                                    10
# xsx                                      4
# yaml                                    15
# yfx                                     15
# zfsendtotarget                           4
#
# [1066 rows x 1 columns]

# %%
# You can rename the Name column in the pivot table as follows:

pivot_table.rename(columns={'Name': 'NumberOfFiles'}, inplace=True)
print(pivot_table)
# Out:
#                                              count
#                                      NumberOfFiles
# Ext
# 1                                                1
# 11                                               3
# 1033                                             4
# 05F0B5F5_44A8_3793_976B_A4F17AECF92C             9
# 07275332_82E4_4820_9FDD_2423CD8DAA85           152
# ...                                            ...
# xslt                                            10
# xsx                                              4
# yaml                                            15
# yfx                                             15
# zfsendtotarget                                   4
#
# [1066 rows x 1 columns]

# %%
# Alternative count like this:

df_counts = df.groupby('Ext').count()['Name']
print(df_counts)
# Out:
# Ext
# 1                                         1
# 11                                        3
# 1033                                      4
# 05F0B5F5_44A8_3793_976B_A4F17AECF92C      9
# 07275332_82E4_4820_9FDD_2423CD8DAA85    152
#                                        ...
# xslt                                     10
# xsx                                       4
# yaml                                     15
# yfx                                      15
# zfsendtotarget                            4
# Name: Name, Length: 1066, dtype: int64

# %%
# Convert to DataFrame for better formatting
df_counts = df_counts.reset_index()

# Rename the columns for clarity
df_counts.columns = ['FileExtension', 'NumberOfFiles']

# Print the result
print(df_counts)
# Out:
#                              FileExtension  NumberOfFiles
# 0                                        1              1
# 1                                       11              3
# 2                                     1033              4
# 3     05F0B5F5_44A8_3793_976B_A4F17AECF92C              9
# 4     07275332_82E4_4820_9FDD_2423CD8DAA85            152
# ...                                    ...            ...
# 1061                                  xslt             10
# 1062                                   xsx              4
# 1063                                  yaml             15
# 1064                                   yfx             15
# 1065                        zfsendtotarget              4
#
# [1066 rows x 2 columns]

# %%
# Let's sort descending on count

sorted_df_counts = df_counts.sort_values(by='NumberOfFiles', ascending=False)
print(sorted_df_counts)
# Out:
#     FileExtension  NumberOfFiles
# 679      manifest          50378
# 200           dll          42653
# 158           cat          33325
# 816           mum          30454
# 703           mui          21810
# ..            ...            ...
# 550  fon_608e9436              1
# 551  fon_70a9c7e3              1
# 552  fon_72a205e7              1
# 553  fon_77baa7cb              1
# 533  fon_3e26940d              1
#
# [1066 rows x 2 columns]

# %%
# which actually is the same as

df['Ext'].value_counts()
# Out:
# manifest        50378
# dll             42653
# cat             33325
# mum             30454
# mui             21810
#                 ...
# fon_5e5746b1        1
# fon_f239c304        1
# fon_85f815ea        1
# fon_8de20802        1
# dll_40d7ce43        1
# Name: Ext, Length: 1066, dtype: int64
